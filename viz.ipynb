# %%
import pandas as pd
import json
import plotly.express as px
from umap import UMAP
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F
# %matplotlib inline

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
model = AutoModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2").to(device)

def get_embedding(inp_text):
    # Tokenize sentences
    encoded_input = tokenizer([inp_text], padding=True, truncation=True, return_tensors="pt").to(device)

    # Compute token embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Perform pooling
    sentence_embeddings = mean_pooling(model_output, encoded_input["attention_mask"])

    # Normalize embeddings
    sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

    return sentence_embeddings[0].detach().cpu().numpy()



embeddings = []

js = json.load(open("neurips2023data.json"))

df = pd.DataFrame(js.values())

df
# Out:
#                                                   title  \
# 0     Language Models Meet World Models: Embodied Ex...
# 1     SAMRS: Scaling-up Remote Sensing Segmentation ...
# 2     On Learning Necessary and Sufficient Causal Gr...
# 3     Dual Self-Awareness Value Decomposition Framew...
# 4     Two-Stage Predict+Optimize for MILPs with Unkn...
# ...                                                 ...
# 3579  Efficient Bayesian Learning Curve Extrapolatio...
# 3580  DICES Dataset: Diversity in Conversational AI ...
# 3581  Phase diagram of early training dynamics in de...
# 3582  Mitigating the Popularity Bias of  Graph Colla...
# 3583  3D Copy-Paste: Physically Plausible Object Ins...
#
#                           presentation_time  \
# 0     We, Dec 13, 15:00 -- Poster Session 4
# 1     Th, Dec 14, 15:00 -- Poster Session 6
# 2     Th, Dec 14, 08:45 -- Poster Session 5
# 3     Tu, Dec 12, 15:15 -- Poster Session 2
# 4     Tu, Dec 12, 15:15 -- Poster Session 2
# ...                                     ...
# 3579  Tu, Dec 12, 08:45 -- Poster Session 1
# 3580  Th, Dec 14, 15:00 -- Poster Session 6
# 3581  Tu, Dec 12, 15:15 -- Poster Session 2
# 3582  We, Dec 13, 08:45 -- Poster Session 3
# 3583  We, Dec 13, 15:00 -- Poster Session 4
#
#                                                 authors  \
# 0     [Jiannan Xiang, Tianhua Tao, Yi Gu, Tianmin Sh...
# 1     [Di Wang, Jing Zhang, Bo Du, Minqiang Xu, Lin ...
# 2     [Hengrui Cai, Yixin Wang, Michael Jordan, Rui ...
# 3     [Zhiwei Xu, Bin Zhang, dapeng li, Guangchong Z...
# 4                     [Xinyi Hu, Jasper Lee, Jimmy Lee]
# ...                                                 ...
# 3579  [Steven Adriaensen, Herilalaina Rakotoarison, ...
# 3580  [Lora Aroyo, Alex Taylor, Mark Díaz, Christoph...
# 3581             [Dayal Singh Kalra, Maissam Barkeshli]
# 3582  [Yifei Zhang, Hao Zhu, yankai Chen, Zixing Son...
# 3583  [Yunhao Ge, Hong-Xing Yu, Cheng Zhao, Yuliang ...
#
#                                                abstract   oral  spotlight  \
# 0     While large language models (LMs) have shown r...  False      False
# 1     The success of the Segment Anything Model (SAM...  False      False
# 2     The causal revolution has stimulated interest ...  False       True
# 3     Value decomposition methods have gained popula...  False      False
# 4     Consider the setting of constrained optimizati...  False      False
# ...                                                 ...    ...        ...
# 3579  Learning curve extrapolation aims to predict m...  False      False
# 3580  Machine learning approaches often require trai...  False      False
# 3581  We systematically analyze optimization dynamic...  False      False
# 3582  Graph-based Collaborative Filtering (GCF) is w...  False       True
# 3583  A major challenge in monocular 3D object detec...  False      False
#
#      oral_presentation_time
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 3579                    NaN
# 3580                    NaN
# 3581                    NaN
# 3582                    NaN
# 3583                    NaN
#
# [3584 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['title', 'presentation_time', 'authors', 'abstract', 'oral',
#        'spotlight', 'oral_presentation_time'],
#       dtype='object')

# %%
for title,row in tqdm(js.items()):
    input_text = row['abstract']
    embedding = get_embedding(input_text)
    embeddings.append(embedding)
    
manifold = UMAP(n_components=2, init="random", random_state=0)
projections = manifold.fit_transform(embeddings)

# %%
fig = px.scatter(
    df, x=projections[:, 0], y=projections[:, 1], hover_name="title", hover_data=["authors"], 
    width=800, height=800, #title="Neurips 2023 papers"
)
# fig.show()

# %%
fig.write_html("file.html")
